# %%
import pandas as pd

# %%
population_data = pd.read_csv("census_population_2019.csv")

# %%
pop_revised = population_data.rename(columns={
    'STATE':'State_code',
    'NAME':'State',
    'POPESTIMATE2019':'population_2019',
    'POPEST18PLUS2019':'increase_18_19',
    'PCNT_POPEST18PLUS':'19_pcnt_increase'
})

# %%
pop_revised
# Out:
#     SUMLEV REGION DIVISION  State_code                     State  \
# 0       10      0        0           0             United States
# 1       40      3        6           1                   Alabama
# 2       40      4        9           2                    Alaska
# 3       40      4        8           4                   Arizona
# 4       40      3        7           5                  Arkansas
# 5       40      4        9           6                California
# 6       40      4        8           8                  Colorado
# 7       40      1        1           9               Connecticut
# 8       40      3        5          10                  Delaware
# 9       40      3        5          11      District of Columbia
# 10      40      3        5          12                   Florida
# 11      40      3        5          13                   Georgia
# 12      40      4        9          15                    Hawaii
# ...

# %%
population_2014 = pd.read_csv("usa_population_2014.csv")

# %%
population_2014.head()
# Out:
#    Rank       State Postal  Population  Unnamed: 4
# 0     1     Alabama     AL     4849377         NaN
# 1     2      Alaska     AK      736732         NaN
# 2     3     Arizona     AZ     6731484         NaN
# 3     4    Arkansas     AR     2966369         NaN
# 4     5  California     CA    38802500         NaN

# %%
pop_data14 = population_2014.rename(columns={
    'Population':'population_2014'})
pop_data14
# Out:
#     Rank                 State Postal  population_2014  Unnamed: 4
# 0      1               Alabama     AL          4849377         NaN
# 1      2                Alaska     AK           736732         NaN
# 2      3               Arizona     AZ          6731484         NaN
# 3      4              Arkansas     AR          2966369         NaN
# 4      5            California     CA         38802500         NaN
# 5      6              Colorado     CO          5355866         NaN
# 6      7           Connecticut     CT          3596677         NaN
# 7      8              Delaware     DE           935614         NaN
# 8      9  District of Columbia     DC           658893         NaN
# 9     10               Florida     FL         19893297         NaN
# 10    11               Georgia     GA         10097343         NaN
# 11    12                Hawaii     HI          1419561         NaN
# 12    13                 Idaho     ID          1634464         NaN
# ...

# %%
population_df = pd.merge(pop_revised,pop_data14,on=['State'],how='outer')
population_df.head()
# Out:
#    SUMLEV REGION DIVISION  State_code          State  population_2019  \
# 0    10.0      0        0         0.0  United States      328239523.0
# 1    40.0      3        6         1.0        Alabama        4903185.0
# 2    40.0      4        9         2.0         Alaska         731545.0
# 3    40.0      4        8         4.0        Arizona        7278717.0
# 4    40.0      3        7         5.0       Arkansas        3017804.0
#
#    increase_18_19  19_pcnt_increase  Rank Postal  population_2014  Unnamed: 4
# 0     255200373.0              77.7   NaN    NaN              NaN         NaN
# 1       3814879.0              77.8   1.0     AL        4849377.0         NaN
# 2        551562.0              75.4   2.0     AK         736732.0         NaN
# 3       5638481.0              77.5   3.0     AZ        6731484.0         NaN
# 4       2317649.0              76.8   4.0     AR        2966369.0         NaN

# %%
population_df['State'].unique()
# Out:
# array(['United States', 'Alabama', 'Alaska', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming',
#        'Puerto Rico Commonwealth', 'Puerto Rico'], dtype=object)

# %%
population_df.head()
# Out:
#            State  population_2019  increase_18_19  19_pcnt_increase  Rank  \
# 0  United States      328239523.0     255200373.0              77.7   NaN
# 1        Alabama        4903185.0       3814879.0              77.8   1.0
# 2         Alaska         731545.0        551562.0              75.4   2.0
# 3        Arizona        7278717.0       5638481.0              77.5   3.0
# 4       Arkansas        3017804.0       2317649.0              76.8   4.0
#
#   Postal  population_2014  Unnamed: 4
# 0    NaN              NaN         NaN
# 1     AL        4849377.0         NaN
# 2     AK         736732.0         NaN
# 3     AZ        6731484.0         NaN
# 4     AR        2966369.0         NaN

# %%
del population_df['Rank']
del population_df['Unnamed: 4']

# %%
population_df.head()
# Out:
#    SUMLEV REGION DIVISION  State_code          State  population_2019  \
# 0    10.0      0        0         0.0  United States      328239523.0
# 1    40.0      3        6         1.0        Alabama        4903185.0
# 2    40.0      4        9         2.0         Alaska         731545.0
# 3    40.0      4        8         4.0        Arizona        7278717.0
# 4    40.0      3        7         5.0       Arkansas        3017804.0
#
#    increase_18_19  19_pcnt_increase Postal  population_2014
# 0     255200373.0              77.7    NaN              NaN
# 1       3814879.0              77.8     AL        4849377.0
# 2        551562.0              75.4     AK         736732.0
# 3       5638481.0              77.5     AZ        6731484.0
# 4       2317649.0              76.8     AR        2966369.0

# %%
del population_df['SUMLEV']
del population_df['REGION']
del population_df['State_code']
del population_df['DIVISION']

# %%
population_df.head()
# Out:
#            State  population_2019  increase_18_19  19_pcnt_increase Postal  \
# 0  United States      328239523.0     255200373.0              77.7    NaN
# 1        Alabama        4903185.0       3814879.0              77.8     AL
# 2         Alaska         731545.0        551562.0              75.4     AK
# 3        Arizona        7278717.0       5638481.0              77.5     AZ
# 4       Arkansas        3017804.0       2317649.0              76.8     AR
#
#    population_2014
# 0              NaN
# 1        4849377.0
# 2         736732.0
# 3        6731484.0
# 4        2966369.0

# %%
population_df1 = population_df.drop(population_df.index[0])

# %%
population_df2 = population_df1.drop(population_df.index[53])

# %%
population_df2['State'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming',
#        'Puerto Rico Commonwealth'], dtype=object)

# %%
population_df2.to_csv("cleaned_us_pop.csv")

# %%
covid_us = pd.read_csv("us-states.csv")
covid_us.head()
# Out:
#          date       state  fips  cases  deaths
# 0  2020-01-21  Washington    53      1       0
# 1  2020-01-22  Washington    53      1       0
# 2  2020-01-23  Washington    53      1       0
# 3  2020-01-24    Illinois    17      1       0
# 4  2020-01-24  Washington    53      1       0

# %%
covid_us.rename(columns={
    'state':'State'
})
# Out:
#             date          State  fips  cases  deaths
# 0     2020-01-21     Washington    53      1       0
# 1     2020-01-22     Washington    53      1       0
# 2     2020-01-23     Washington    53      1       0
# 3     2020-01-24       Illinois    17      1       0
# 4     2020-01-24     Washington    53      1       0
# ...          ...            ...   ...    ...     ...
# 1659  2020-04-01       Virginia    51   1511      34
# 1660  2020-04-01     Washington    53   5588     249
# 1661  2020-04-01  West Virginia    54    191       2
# 1662  2020-04-01      Wisconsin    55   1550      33
# 1663  2020-04-01        Wyoming    56    137       0
#
# [1664 rows x 5 columns]

# %%
for i in range(len(covid_us)): 
    if covid_us["State"][i] == "Alabama": 
        Postal[i]="AL"
  
    elif covid_us["State"][i] == "Alaska": 
        Postal[i]="AK"
  
    elif covid_us["Type"][i] == "Water": 
        Type_new[i]="Blue"
  
    else: 
        Type_new[i]= data["Type"][i]
